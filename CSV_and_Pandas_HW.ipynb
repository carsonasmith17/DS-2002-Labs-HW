# %% [markdown]
# <a href="https://colab.research.google.com/github/carsonasmith17/DS-2002-Labs-HW/blob/main/CSV_and_Pandas_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assignment Tasks:
# 1. Reading the CSV File:
# - Load the provided CSV file into a pandas DataFrame.
# - Display the first 5 rows of the DataFrame to understand the structure of the data.
# 2. Basic Analysis:
# - Calculate the total points scored by all players combined.
# - Find the player who has played the most minutes (MP).
# - Identify the top 5 players in terms of total rebounds (TRB).
# 3. Player Filtering:
# - Create a new DataFrame containing only players who played more than 500 minutes.
# - From this filtered DataFrame, determine the player with the highest total assists (AST).
# - Who are the top 3 Assist Leads in the League?
# - Who are the top 3 Shot Blockers?
# 4. School-Based Analysis:
# - Group the players by School and calculate the total points scored by each school.
# - Group the players by School and calculate the total assists (AST) for each team.
# - Sort the schools by total points scored and display the top 3 schools.
# 5. Extra Credit (Bonus):
# - Create a bar chart showing the top 5 players by total points scored (PTS).
# - Correlation: Investigate whether there is any correlation between a player's field goal
# percentage (FG%) and their win shares (WS). Provide a scatter plot and calculate the
# correlation coefficient.

# %%
df = pd.read_csv('acc_players-2324F (1).csv', skiprows = 1)
df.head()
# Out:
#    Rk         Player Class Pos          School   G   MP  TRB  AST  STL  ...  \
# 0   1   Amaree Abram    SO   G    Georgia Tech  10  108   17   11    1  ...
# 1   2   Sola Adebisi    FR   F   Florida State   7    9    1    1    0  ...
# 2   3  Prince Aligbe    SO   F  Boston College  35  651  119   21   15  ...
# 3   4     Abe Atiyeh    SR   G  Boston College   4    6    0    0    0  ...
# 4   5    Zack Austin    JR   F      Pittsburgh  33  746  137   29   32  ...
#
#    TOV  PF  PTS    FG%    2P%    3P%    FT%   PER   WS  BPM
# 0    9  10   34  0.262  0.318  0.200  0.615   4.1 -0.1 -6.4
# 1    1   1    2  0.500  0.500    NaN    NaN   3.5  0.0 -6.7
# 2   30  51  164  0.435  0.522  0.147  0.620   9.4  0.9 -1.3
# 3    1   0    3  0.333  0.000  1.000    NaN   1.1  0.0 -8.2
# 4   13  35  216  0.417  0.563  0.295  0.737  18.0  2.9  7.9
#
# [5 rows x 21 columns]

# %%
df['PTS'].sum()
# Out:
# 38411

# %%
df.loc[df['MP'].idxmax()]
# Out:
# Rk                  136
# Player    Casey Morsell
# Class                SR
# Pos                   G
# School         NC State
# G                    41
# MP                 1333
# TRB                 114
# AST                  67
# STL                  46
# BLK                  19
# TOV                  38
# PF                   86
# PTS                 455
# FG%               0.406
# 2P%               0.478
# 3P%                0.27
# FT%               0.806
# PER                13.4
# WS                  3.2
# BPM                 2.5
# Name: 135, dtype: object

# %%
df.nlargest(5, 'TRB')
# Out:
#       Rk           Player Class Pos          School   G    MP  TRB  AST  STL  \
# 5      6    Armando Bacot    SR   F  North Carolina  37  1123  380   56   22
# 178  179  Ian Schieffelin    JR   F         Clemson  36   989  340   80   21
# 90    91  Harrison Ingram    SO   F  North Carolina  37  1213  327   80   51
# 44    45   Mohamed Diarra    SR   F        NC State  40   882  311   24   28
# 149  150    Norchad Omier    JR   F      Miami (FL)  31   948  309   38   47
#
#      ...  TOV   PF  PTS    FG%    2P%    3P%    FT%   PER   WS  BPM
# 5    ...   60  100  538  0.540  0.544  0.400  0.781  24.6  6.1  8.9
# 178  ...   45   95  365  0.564  0.588  0.469  0.731  22.5  4.9  8.8
# 90   ...   51   71  451  0.430  0.467  0.385  0.612  18.3  4.9  8.5
# 44   ...   26   66  253  0.477  0.568  0.309  0.658  18.9  3.4  6.2
# 149  ...   72   91  528  0.552  0.598  0.353  0.750  26.8  4.7  6.6
#
# [5 rows x 21 columns]

# %%
new_df = df[df['MP'] > 500]
new_df.head(100)
# Out:
#       Rk            Player Class Pos          School   G    MP  TRB  AST  STL  \
# 2      3     Prince Aligbe    SO   F  Boston College  35   651  119   21   15
# 4      5       Zack Austin    JR   F      Pittsburgh  33   746  137   29   32
# 5      6     Armando Bacot    SR   F  North Carolina  37  1123  380   56   22
# 7      8     Reece Beekman    SR   G        Virginia  34  1114  124  212   68
# 9     10        Chris Bell    SO   F        Syracuse  32   865   75   21   18
# ..   ...               ...   ...  ..             ...  ..   ...  ...  ...  ...
# 203  204     Jamir Watkins    JR   F   Florida State  33   928  199   91   64
# 206  207         Tre White    SO   G      Louisville  29   907  170   39   24
# 207  208  Chauncey Wiggins    SO   F         Clemson  36   639   76   33    6
# 209  210   Curtis Williams    FR   G      Louisville  32   564   42   20   12
# 215  216    Jaeden Zackery    JR   G  Boston College  36  1216  119  152   63
#
# ...

# %%
new_df.loc[new_df['AST'].idxmax()]
# Out:
# Rk                    8
# Player    Reece Beekman
# Class                SR
# Pos                   G
# School         Virginia
# G                    34
# MP                 1114
# TRB                 124
# AST                 212
# STL                  68
# BLK                  17
# TOV                  70
# PF                   43
# PTS                 486
# FG%               0.443
# 2P%               0.487
# 3P%                0.31
# FT%               0.754
# PER                23.4
# WS                  4.9
# BPM                10.5
# Name: 7, dtype: object

# %% [markdown]
# wahoowa!

# %%
df.nlargest(3, 'AST')
# Out:
#       Rk          Player Class Pos          School   G    MP  TRB  AST  STL  \
# 7      8   Reece Beekman    SR   G        Virginia  34  1114  124  212   68
# 215  216  Jaeden Zackery    JR   G  Boston College  36  1216  119  152   63
# 21    22   Elliot Cadeau    FR   G  North Carolina  37   882   81  150   29
#
#      ...  TOV  PF  PTS    FG%    2P%    3P%    FT%   PER   WS   BPM
# 7    ...   70  43  486  0.443  0.487  0.310  0.754  23.4  4.9  10.5
# 215  ...   71  78  408  0.484  0.511  0.405  0.824  16.4  3.7   3.5
# 21   ...   67  84  271  0.417  0.481  0.189  0.648  11.7  2.1   1.8
#
# [3 rows x 21 columns]

# %%
df.nlargest(3, 'STL')
# Out:
#       Rk         Player Class Pos    School   G    MP  TRB  AST  STL  ...  \
# 16    17    Maliq Brown    SO   F  Syracuse  32   948  230   59   71  ...
# 7      8  Reece Beekman    SR   G  Virginia  34  1114  124  212   68  ...
# 132  133    Judah Mintz    SO   G  Syracuse  32  1084  103  142   67  ...
#
#      TOV  PF  PTS    FG%    2P%    3P%    FT%   PER   WS   BPM
# 16    41  97  305  0.698  0.736  0.368  0.721  22.0  4.3   7.4
# 7     70  43  486  0.443  0.487  0.310  0.754  23.4  4.9  10.5
# 132   94  70  602  0.438  0.477  0.282  0.765  20.5  3.5   4.2
#
# [3 rows x 21 columns]

# %%
df.groupby('School')['PTS'].sum()
# Out:
# School
# Boston College    2667
# Clemson           2785
# Duke              2830
# Florida State     2526
# Georgia Tech      2272
# Louisville        2304
# Miami (FL)        2424
# NC State          3101
# North Carolina    3032
# Notre Dame        2113
# Pittsburgh        2495
# Syracuse          2442
# Virginia          2140
# Virginia Tech     2547
# Wake Forest       2733
# Name: PTS, dtype: int64

# %%
df.groupby('School')['AST'].sum()
# Out:
# School
# Boston College    509
# Clemson           533
# Duke              551
# Florida State     406
# Georgia Tech      425
# Louisville        356
# Miami (FL)        454
# NC State          536
# North Carolina    536
# Notre Dame        335
# Pittsburgh        452
# Syracuse          442
# Virginia          509
# Virginia Tech     514
# Wake Forest       429
# Name: AST, dtype: int64

# %%
df.nlargest(3, 'PTS')
# Out:
#     Rk    Player Class Pos          School   G    MP  TRB  AST  STL  ...  TOV  \
# 42  43  RJ Davis    SR   G  North Carolina  37  1287  134  129   45  ...   55
# 81  82  DJ Horne    SR   G        NC State  40  1304  138   84   51  ...   54
# 70  71   PJ Hall    SR   F         Clemson  36  1040  231   51   28  ...   67
#
#      PF  PTS    FG%    2P%    3P%    FT%   PER   WS   BPM
# 42   65  784  0.428  0.455  0.398  0.873  22.7  6.7  10.8
# 81   80  677  0.436  0.464  0.404  0.814  19.3  4.6   6.5
# 70  113  659  0.488  0.575  0.315  0.779  25.6  4.8   8.4
#
# [3 rows x 21 columns]

# %%
df_school = df.groupby('School')['PTS'].sum()
df_school.nlargest(3)
# Out:
# School
# NC State          3101
# North Carolina    3032
# Duke              2830
# Name: PTS, dtype: int64

# %%
import matplotlib.pyplot as plt

top_5_players = df.nlargest(5, 'PTS')
plt.bar(top_5_players['Player'], top_5_players['PTS'])
plt.xlabel('Player')
plt.ylabel('Total Points')
plt.title('Top 5 Players by Total Points Scored')
plt.xticks(rotation=45)
plt.show()

# %%
plt.scatter(df['FG%'], df['WS'])
plt.xlabel('Field Goal Percentage (FG%)')
plt.ylabel('Win Shares (WS)')
plt.title('Correlation between FG% and WS')
plt.show()

correlation = df['FG%'].corr(df['WS'])
print("Correlation coefficient between FG% and WS:", correlation)
# Out:
# Correlation coefficient between FG% and WS: 0.4210663894199787

# %% [markdown]
# 1. The simple manipulation of where you want to start your data from a CSV was probably my biggest discovery in this assignment, and would absolutely be something to take with me in any future career path involving data. While I had previously been aware of the other cleaning tools, and a large part of this assignment was mainly serving as a refresher, I wasn't aware the CSV could function more as just an input, but also manipulate the data in the dataframe. This woule be an incredibly helpful skill in any futre work area where any data needs clenaing on an excel sheet, but the sheet was created in a way that made retreiving data inefficent, whether that be attributed to miscelaneuos names/labels or spaces/indents in the sheet.

# %% [markdown]
# 2. My inital streggles began upon importing the CSV and being presented with the 'Unnamed: X' labels in the index. I was a bit perplexed about how to go about cleaning this from the data, and tried finctions such as .drop, yet that didnt work. Upon some googling eventaully i fugred out that you actually had to manipulate the csv to decide where you wanted your data to star. I hadnt worked with Pandas in depth in a bit, and forgot somet of the main functions like .iloc/.loc and others. I also wasn't at first aware of the nlargest funciton, so had to use w3schools and pypandas sites to figure this out. I also somewhat worked backwards, using .shape function to figure out how many rows were in the new_df I had just created in part 3, because when I printed the new_df it wasnt as clean/aestetically pleasing  as other tables I had just created. Thus, i would need to put in the .head(100) to list the players that had over 500 points. I decided to do 100 because when I did the .shape function, it gave me the dimensions (98, 21) for new_df.

# %% [markdown]
# 3. deriving more deatailed data frames from preexisting data frames is certainly a skill that can be applied in any field, especially when considering the immense data that is being collected ans stored on a day-to-day basis.  This data can range from a more granual level such as the amount of time an individual consumer spends browsing cowboy boots online, to a much broader level like the amount of money spent on advertiasing Boot Barn does every year. Regardless of the level, the ability to iterate new data from larger data frames can be applied to any field.
